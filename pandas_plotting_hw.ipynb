# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Homework: Plotting With Pandas
#
# _Authors: Kevin Coyle (L.A.)_
#
# ---

# %% [markdown]
# Welcome!

# %% [markdown]
# #### Pandas: Plotting Practice Problems
#
# In this homework, you're going to write code for a few problems.
#
# You'll practice the following programming concepts we've covered in class:
# * Plotting with Pandas.
# * Determining best plot given a data set.

# %% [markdown]
# #### #1. Import Pandas, `Matplotlib.pyplot`, and NumPy. Don't forget the line that makes `matplotlib` render in a Jupyter Notebook!

# %%
import matplotlib
from matplotlib import pyplot as plt
import numpy
import csv
import pandas as pd

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba_df`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `NBA_players_2015.csv`.

# %%
nba_df = pd.read_csv('NBA_players_2015.csv')
print((nba_df.head(5)))
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...   15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...   19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...   12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...   10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #3. Look at the first five rows of the data set.

# %%
print(nba_df.head(5))
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...   TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...   15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...   15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...   19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...   12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...   10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #4. Create a histogram of the `age` column.

# %%
hist = nba_df['age'].hist()
print(hist)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# #### #5. Create a histogram of the `age` column, but change the number of bins to `20`.

# %%
plt.hist(nba_df['age'], bins=20)
# Out:
# (array([ 8., 12., 24., 31., 56., 48., 39., 44., 35., 37., 34., 23., 16.,
#         18., 14., 19.,  6.,  4.,  6.,  4.]),
#  array([19.  , 19.95, 20.9 , 21.85, 22.8 , 23.75, 24.7 , 25.65, 26.6 ,
#         27.55, 28.5 , 29.45, 30.4 , 31.35, 32.3 , 33.25, 34.2 , 35.15,
#         36.1 , 37.05, 38.  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# #### #6. Discuss the difference in the two plots and the implications.

# %% [markdown]
# While skewed, the plot with fewer bins leads one to believe that the bin to the right of the highest-numbered age bin is the second largest. The second-largest bin occurs right after 22 and before 25.

# %% [markdown]
# #### #7. Rename the `position` column `'pos'` with the following `C:5`, `G:1`, and `F:3`. Then create a scatter matrix plot with the `'pos'`, `'pts'`, `'age'`, and `'fg'` columns.

# %%
nba_df['pos'] = nba_df['pos'].replace({'F':3, 'C':5, 'G':1})
print(nba_df['pos'])
# Out:
# 0      3
# 1      1
# 2      5
# 3      3
# 4      1
# 5      5
# 6      3
# 7      5
# 8      3
# 9      3
# 10     1
# 11     3
# 12     3
# 13     5
# 14     1
# 15     3
# 16     3
# 17     1
# 18     3
# 19     5
# 20     3
# 21     3
# 22     3
# 23     5
# 24     1
# 25     3
# 26     3
# 27     3
# 28     1
# 29     1
#       ..
# 448    1
# 449    3
# 450    3
# 451    1
# 452    3
# 453    3
# 454    3
# 455    1
# 456    5
# 457    3
# 458    1
# 459    1
# 460    1
# 461    3
# 462    1
# 463    1
# 464    3
# 465    1
# 466    3
# 467    3
# 468    5
# 469    1
# 470    3
# 471    3
# 472    1
# 473    1
# 474    1
# 475    3
# 476    5
# 477    5
# Name: pos, Length: 478, dtype: int64

# %%
# data = (nba_df[['pos','age', 'pts', 'fg']])
# data.plot(style='.')

pd.plotting.scatter_matrix(nba_df[['pos', 'age', 'pts', 'fg']], figsize=(14,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002753F5EB668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002753F64ABA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002753F671160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000275406676D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027540690C50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000275406C1208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000275406E9780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027540710D30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000027540710D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002754076A828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027540793DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000275407C4358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000275407E98D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027540812E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027540845400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002754086C978>]],
#       dtype=object)

# %% [markdown]
# #### #8. Plot the number of guards, centers, and forwards in this data set.

# %%
nba_df['pos'].value_counts().plot(kind='bar')

# %% [markdown]
# The end!

# %% [markdown]
# #### Great job!
